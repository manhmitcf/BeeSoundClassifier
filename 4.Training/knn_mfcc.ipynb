# %%
import pandas as pd
import numpy as np
import time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import os

# Hàm load dữ liệu theo batch
def load_data_by_batch(csv_path, batch_id):
    df = pd.read_csv(csv_path)

    if "Bộ" not in df.columns:
        print("⚠️ Lỗi: Cột 'Bộ' không có trong file CSV!")
        return None

    df["Bộ"] = df["Bộ"].astype(int)
    batch_df = df[df["Bộ"] == batch_id]

    if batch_df.empty:
        print(f"⚠️ Batch {batch_id} không có dữ liệu trong CSV!")
        return None

    n_fft = batch_df["n_fft"].values[0]
    hop_length = batch_df["hop_length"].values[0]

    train_row = batch_df[batch_df["Tập"] == "train"]
    test_row = batch_df[batch_df["Tập"] == "test"]

    try:
        train_x_path = train_row["X_file_path"].values[0]
        train_y_path = train_row["y_file_path"].values[0]
        test_x_path = test_row["X_file_path"].values[0]
        test_y_path = test_row["y_file_path"].values[0]

        if not (os.path.exists(train_x_path) and os.path.exists(train_y_path) and os.path.exists(test_x_path) and os.path.exists(test_y_path)):
            print(f"⚠️ Lỗi: Một trong các file .npy của batch {batch_id} không tồn tại!")
            return None

        X_train = np.load(train_x_path)
        y_train = np.load(train_y_path)
        X_test = np.load(test_x_path)
        y_test = np.load(test_y_path)
    
    except Exception as e:
        print(f"⚠️ Lỗi khi load dữ liệu batch {batch_id}: {e}")
        return None

    return X_train, y_train, X_test, y_test, n_fft, hop_length

# Hàm chạy KNN với nhiều mức MFCC
def run_knn_experiment(X_train, y_train, X_test, y_test, n_fft, hop_length, mfcc_steps):
    scaler = StandardScaler()

    # Scale toàn bộ MFCC
    num_samples_train, num_features = X_train.shape
    num_samples_test = X_test.shape[0]

    X_train_scaled = scaler.fit_transform(X_train.reshape(num_samples_train, -1))
    X_test_scaled = scaler.transform(X_test.reshape(num_samples_test, -1))

    knn = KNeighborsClassifier()
    knn_params = {
        'n_neighbors': list(range(1, 21)),  # Tìm số k từ 1 đến 20
        'weights': ['uniform', 'distance'],  # Kiểu tính trọng số
        'metric': ['euclidean', 'manhattan', 'minkowski']  # Khoảng cách
    }

    results = []
    for i in mfcc_steps:
        print(f"▶ Đang thử nghiệm với {i} MFCC...")

        X_train_subset = X_train_scaled[:, :i]
        X_test_subset = X_test_scaled[:, :i]

        start_time = time.time()

        # Random search với ít fold hơn để tăng tốc
        random_search = RandomizedSearchCV(knn, knn_params, n_iter=10, cv=3, random_state=42, n_jobs=-1)
        random_search.fit(X_train_subset, y_train)

        best_params = random_search.best_params_
        y_pred = random_search.predict(X_test_subset)

        test_accuracy = accuracy_score(y_test, y_pred)
        macro_f1 = f1_score(y_test, y_pred, average='macro')
        confusion = confusion_matrix(y_test, y_pred)

        print(f"🔹 MFCC: {i}, Best K: {best_params['n_neighbors']}")
        print("Confusion Matrix:\n", confusion)

        elapsed_time = time.time() - start_time

        # Lưu kết quả
        results.append({
            'numofMFCC': i,
            'n_fft': n_fft,
            'Hop_length': hop_length,
            'Best_hyperparameters': best_params,
            'test_accuracy': test_accuracy,
            'macro_f1': macro_f1,
            'time': elapsed_time
        })

    return pd.DataFrame(results)

# Chạy thử nghiệm
mfcc_steps = [13, 20, 40, 80]
csv_path = r"C:\Users\manhm\Desktop\BeeSoundClassifier\data\extracted_features\mfcc\mfcc_extraction_log.csv"

for batch_id in range(4):
    print(f"\n🚀 Chạy thử nghiệm Batch {batch_id}...")
    data = load_data_by_batch(csv_path, batch_id)

    if data is None:
        continue  # Nếu batch không có dữ liệu, bỏ qua

    X_train, y_train, X_test, y_test, n_fft, hop_length = data
    df = run_knn_experiment(X_train, y_train, X_test, y_test, n_fft, hop_length, mfcc_steps)

    print(f"\n📌 Kết quả Batch {batch_id}:")
    print(df)

    result_path = f"knn_results_batch_{batch_id}.csv"
    df.to_csv(result_path, index=False)
    print(f"✅ Đã lưu kết quả vào {result_path}")
# Out:
# 🚀 Chạy thử nghiệm Batch 0...
# ▶ Đang thử nghiệm với 13 MFCC...
# 🔹 MFCC: 13, Best K: 17
# Confusion Matrix:
#  [[1008   70   17]
#  [ 121  364  207]
#  [   2   18  953]]
# ▶ Đang thử nghiệm với 20 MFCC...
# 🔹 MFCC: 20, Best K: 17
# Confusion Matrix:
#  [[1033   57    5]
#  [ 127  357  208]
#  [   0   22  951]]
# ▶ Đang thử nghiệm với 40 MFCC...
# 🔹 MFCC: 40, Best K: 14
# Confusion Matrix:
#  [[1053   40    2]
#  [ 140  351  201]
#  [   0   29  944]]
# ▶ Đang thử nghiệm với 80 MFCC...
# 🔹 MFCC: 80, Best K: 14
# Confusion Matrix:
#  [[1063   30    2]
#  [ 127  365  200]
#  [   2   27  944]]
#
# 📌 Kết quả Batch 0:
#    numofMFCC  n_fft  Hop_length  \
# 0         13   1024         256
# 1         20   1024         256
# 2         40   1024         256
# 3         80   1024         256
#
#                                 Best_hyperparameters  test_accuracy  macro_f1  \
# 0  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.842391  0.809512
# 1  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.848188  0.813066
# 2  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.850725  0.814105
# 3  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.859420  0.825295
#
#        time
# 0  6.371916
# 1  2.381403
# 2  2.861518
# 3  4.816396
# ✅ Đã lưu kết quả vào knn_results_batch_0.csv
#
# 🚀 Chạy thử nghiệm Batch 1...
# ▶ Đang thử nghiệm với 13 MFCC...
# 🔹 MFCC: 13, Best K: 14
# Confusion Matrix:
#  [[1018   62   15]
#  [ 139  352  201]
#  [   3   28  942]]
# ▶ Đang thử nghiệm với 20 MFCC...
# 🔹 MFCC: 20, Best K: 17
# Confusion Matrix:
#  [[1029   62    4]
#  [ 126  352  214]
#  [   0   22  951]]
# ▶ Đang thử nghiệm với 40 MFCC...
# 🔹 MFCC: 40, Best K: 17
# Confusion Matrix:
#  [[1041   52    2]
#  [ 127  360  205]
#  [   0   24  949]]
# ▶ Đang thử nghiệm với 80 MFCC...
# 🔹 MFCC: 80, Best K: 17
# Confusion Matrix:
#  [[1052   38    5]
#  [ 125  350  217]
#  [   1   16  956]]
#
# 📌 Kết quả Batch 1:
#    numofMFCC  n_fft  Hop_length  \
# 0         13   1024         512
# 1         20   1024         512
# 2         40   1024         512
# 3         80   1024         512
#
#                                 Best_hyperparameters  test_accuracy  macro_f1  \
# 0  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.837681  0.802595
# 1  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.844928  0.808912
# 2  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.851449  0.816605
# 3  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.854348  0.817741
#
#        time
# 0  1.679070
# 1  1.655791
# 2  2.794628
# 3  4.672265
# ✅ Đã lưu kết quả vào knn_results_batch_1.csv
#
# 🚀 Chạy thử nghiệm Batch 2...
# ▶ Đang thử nghiệm với 13 MFCC...
# 🔹 MFCC: 13, Best K: 14
# Confusion Matrix:
#  [[1013   68   14]
#  [ 132  356  204]
#  [   3   32  938]]
# ▶ Đang thử nghiệm với 20 MFCC...
# 🔹 MFCC: 20, Best K: 17
# Confusion Matrix:
#  [[1031   60    4]
#  [ 127  354  211]
#  [   0   21  952]]
# ▶ Đang thử nghiệm với 40 MFCC...
# 🔹 MFCC: 40, Best K: 14
# Confusion Matrix:
#  [[1052   41    2]
#  [ 149  340  203]
#  [   1   25  947]]
# ▶ Đang thử nghiệm với 80 MFCC...
# 🔹 MFCC: 80, Best K: 14
# Confusion Matrix:
#  [[1057   37    1]
#  [ 121  365  206]
#  [   2   17  954]]
#
# 📌 Kết quả Batch 2:
#    numofMFCC  n_fft  Hop_length  \
# 0         13   2048         512
# 1         20   2048         512
# 2         40   2048         512
# 3         80   2048         512
#
#                                 Best_hyperparameters  test_accuracy  macro_f1  \
# 0  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.835870  0.801543
# 1  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.846739  0.811053
# 2  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.847464  0.808860
# 3  {'weights': 'distance', 'n_neighbors': 14, 'me...       0.860870  0.826797
#
#        time
# 0  1.633983
# 1  1.626320
# 2  2.909235
# 3  4.700016
# ✅ Đã lưu kết quả vào knn_results_batch_2.csv
#
# 🚀 Chạy thử nghiệm Batch 3...
# ▶ Đang thử nghiệm với 13 MFCC...
# 🔹 MFCC: 13, Best K: 14
# Confusion Matrix:
#  [[1017   65   13]
#  [ 132  360  200]
#  [   2   32  939]]
# ▶ Đang thử nghiệm với 20 MFCC...
# 🔹 MFCC: 20, Best K: 17
# Confusion Matrix:
#  [[1027   65    3]
#  [ 125  356  211]
#  [   0   23  950]]
# ▶ Đang thử nghiệm với 40 MFCC...
# 🔹 MFCC: 40, Best K: 17
# Confusion Matrix:
#  [[1046   47    2]
#  [ 130  348  214]
#  [   0   22  951]]
# ▶ Đang thử nghiệm với 80 MFCC...
# 🔹 MFCC: 80, Best K: 14
# Confusion Matrix:
#  [[1056   37    2]
#  [ 114  368  210]
#  [   1   17  955]]
#
# 📌 Kết quả Batch 3:
#    numofMFCC  n_fft  Hop_length  \
# 0         13   2048        1024
# 1         20   2048        1024
# 2         40   2048        1024
# 3         80   2048        1024
#
#                                 Best_hyperparameters  test_accuracy  macro_f1  \
# 0  {'weights': 'uniform', 'n_neighbors': 14, 'met...       0.839130  0.805336
# 1  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.845290  0.809988
# 2  {'weights': 'distance', 'n_neighbors': 17, 'me...       0.849638  0.812519
# 3  {'weights': 'distance', 'n_neighbors': 14, 'me...       0.861957  0.828415
#
#        time
# 0  4.458395
# 1  2.987477
# 2  5.413595
# 3  7.524879
# ✅ Đã lưu kết quả vào knn_results_batch_3.csv
